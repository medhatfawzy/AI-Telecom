# %%
import pandas as pd

# %%
RSRP_data = pd.read_parquet("RSRP_data.parq")
Traffic_volumn_data = pd.read_parquet("Traffic_volumn_data.parq")

# %%
RSRP_data.head(20)
# Out:
#                           Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-01 21:09:29.386000+00:00          24.54054          46.784737
# 1  2019-11-01 21:09:29.386000+00:00          24.54054          46.784737
# 2  2019-11-01 21:10:45.323000+00:00          24.54054          46.784737
# 3  2019-11-01 21:10:45.323000+00:00          24.54054          46.784737
# 4  2019-11-01 21:11:26.822000+00:00          24.54054          46.784737
# 5  2019-11-01 21:11:26.822000+00:00          24.54054          46.784737
# 6  2019-11-01 21:17:44.340000+00:00          24.54054          46.784737
# 7  2019-11-01 21:17:44.340000+00:00          24.54054          46.784737
# 8  2019-11-01 21:23:41.693000+00:00          24.54054          46.784737
# 9  2019-11-01 21:23:41.693000+00:00          24.54054          46.784737
# 10 2019-11-01 21:23:42.756000+00:00          24.54054          46.784737
# 11 2019-11-01 21:23:42.756000+00:00          24.54054          46.784737
# 12 2019-11-01 21:23:43.816000+00:00          24.54054          46.784737
# 13 2019-11-01 21:23:43.816000+00:00          24.54054          46.784737
# 14 2019-11-01 21:23:44.886000+00:00          24.54054          46.784737
# 15 2019-11-01 21:23:44.886000+00:00          24.54054          46.784737
# 16 2019-11-01 21:23:50.222000+00:00          24.54054          46.784737
# 17 2019-11-01 21:23:50.222000+00:00          24.54054          46.784737
# 18 2019-11-01 21:25:31.715000+00:00          24.54054          46.784737
# 19 2019-11-01 21:25:31.715000+00:00          24.54054          46.784737
#
#    RadioConnectionType RadioNetworkGeneration RadioOperatorName        RSRP  \
# 0               Mobile                     4G        Operator C  2147483647
# 1               Mobile                     4G        Operator C  2147483647
# 2               Mobile                     3G        Operator C  2147483647
# 3               Mobile                     3G        Operator C  2147483647
# 4               Mobile                     4G        Operator C  2147483647
# 5               Mobile                     4G        Operator C  2147483647
# 6               Mobile                     3G        Operator C  2147483647
# 7               Mobile                     3G        Operator C  2147483647
# 8               Mobile                     2G        Operator C  2147483647
# 9               Mobile                     2G        Operator C  2147483647
# 10              Mobile                     2G        Operator C  2147483647
# 11              Mobile                     2G        Operator C  2147483647
# 12              Mobile                     2G        Operator C  2147483647
# 13              Mobile                     2G        Operator C  2147483647
# 14              Mobile                     2G        Operator C  2147483647
# 15              Mobile                     2G        Operator C  2147483647
# 16              Mobile                     2G        Operator C  2147483647
# 17              Mobile                     2G        Operator C  2147483647
# 18              Mobile                     2G        Operator C  2147483647
# 19              Mobile                     2G        Operator C  2147483647
#
#    RadioMobileDataEnabled DeviceManufacturer           DeviceName
# 0                 Enabled                HTC                D728W
# 1                 Enabled                HTC  Desire 728 Dual Sim
# 2                 Enabled                HTC                D728W
# 3                 Enabled                HTC  Desire 728 Dual Sim
# 4                 Enabled                HTC                D728W
# 5                 Enabled                HTC  Desire 728 Dual Sim
# 6                 Enabled                HTC                D728W
# 7                 Enabled                HTC  Desire 728 Dual Sim
# 8                 Enabled                HTC                D728W
# 9                 Enabled                HTC  Desire 728 Dual Sim
# 10                Enabled                HTC                D728W
# 11                Enabled                HTC  Desire 728 Dual Sim
# 12                Enabled                HTC                D728W
# 13                Enabled                HTC  Desire 728 Dual Sim
# 14                Enabled                HTC                D728W
# 15                Enabled                HTC  Desire 728 Dual Sim
# 16                Enabled                HTC                D728W
# 17                Enabled                HTC  Desire 728 Dual Sim
# 18                Enabled                HTC                D728W
# 19                Enabled                HTC  Desire 728 Dual Sim

# %%
RSRP_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2725353 entries, 0 to 2725352
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Timestamp               datetime64[ns, UTC]
#  1   LocationLatitude        float64
#  2   LocationLongitude       float64
#  3   RadioConnectionType     object
#  4   RadioNetworkGeneration  object
#  5   RadioOperatorName       object
#  6   RSRP                    int64
#  7   RadioMobileDataEnabled  object
#  8   DeviceManufacturer      object
#  9   DeviceName              object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(1), object(6)
# memory usage: 207.9+ MB

# %%
Traffic_volumn_data.head(20)
# Out:
#                    Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-01 18:00:00+00:00         24.639288          46.728962
# 1  2019-11-01 18:00:00+00:00         24.639288          46.728962
# 2  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 3  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 4  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 5  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 6  2019-11-01 18:30:00+00:00         24.626589          46.689250
# 7  2019-11-01 18:30:00+00:00         24.626589          46.689250
# 8  2019-11-01 18:30:00+00:00         24.626589          46.689250
# 9  2019-11-01 18:30:00+00:00         24.626589          46.689250
# 10 2019-11-01 18:30:00+00:00         24.639288          46.728962
# 11 2019-11-01 18:30:00+00:00         24.639288          46.728962
# 12 2019-11-01 18:45:00+00:00         24.626589          46.689250
# 13 2019-11-01 18:45:00+00:00         24.626589          46.689250
# 14 2019-11-01 18:45:00+00:00         24.640503          46.716290
# 15 2019-11-01 18:45:00+00:00         24.641806          46.715973
# 16 2019-11-01 19:00:00+00:00         24.619022          46.721550
# 17 2019-11-01 19:00:00+00:00         24.619022          46.721550
# 18 2019-11-01 19:00:00+00:00         24.626589          46.689250
# 19 2019-11-01 19:00:00+00:00         24.626589          46.689250
#
#    RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0               Mobile                     4G        Operator B
# 1               Mobile                     4G        Operator B
# 2               Mobile                     3G        Operator B
# 3               Mobile                     4G        Operator B
# 4               Mobile                     3G        Operator B
# 5               Mobile                     4G        Operator B
# 6               Mobile                     4G        Operator C
# 7               Mobile                     4G        Operator C
# 8               Mobile                     4G        Operator C
# 9               Mobile                     4G        Operator C
# 10              Mobile                     4G        Operator B
# 11              Mobile                     4G        Operator B
# 12              Mobile                     4G        Operator C
# 13              Mobile                     4G        Operator C
# 14              Mobile                     4G        Operator B
# 15              Mobile                     4G        Operator B
# 16              Mobile                     4G        Operator B
# 17              Mobile                     4G        Operator B
# 18              Mobile                     4G        Operator C
# 19              Mobile                     4G        Operator C
#
#    TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0          Downlink      45.701516                Enabled
# 1            Uplink       1.740874                Enabled
# 2          Downlink       5.182752                Enabled
# 3          Downlink      30.303686                Enabled
# 4            Uplink       0.390352                Enabled
# 5            Uplink       1.083652                Enabled
# 6            Uplink       0.011245                Enabled
# 7          Downlink       2.263094                Enabled
# 8          Downlink       0.005951                Enabled
# 9            Uplink       1.889517                Enabled
# 10         Downlink       0.056850                Enabled
# 11           Uplink       0.069332                Enabled
# 12         Downlink       2.743515                Enabled
# 13           Uplink       2.470590                Enabled
# 14         Downlink       8.589538                Enabled
# 15           Uplink       0.337878                Enabled
# 16         Downlink       0.331708                Enabled
# 17           Uplink       0.133907                Enabled
# 18           Uplink       2.151763                Enabled
# 19         Downlink       2.475489                Enabled

# %%
Traffic_volumn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138359 entries, 0 to 138358
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138359 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138359 non-null  float64
#  2   LocationLongitude       138359 non-null  float64
#  3   RadioConnectionType     138359 non-null  category
#  4   RadioNetworkGeneration  138359 non-null  category
#  5   RadioOperatorName       138359 non-null  category
#  6   TrafficDirection        138359 non-null  category
#  7   TrafficVolume           138359 non-null  float64
#  8   RadioMobileDataEnabled  138359 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 4.9 MB

# %%
Traffic_volumn_data.drop_duplicates(inplace=True)

# %%
Traffic_volumn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138359 entries, 0 to 138358
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138359 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138359 non-null  float64
#  2   LocationLongitude       138359 non-null  float64
#  3   RadioConnectionType     138359 non-null  category
#  4   RadioNetworkGeneration  138359 non-null  category
#  5   RadioOperatorName       138359 non-null  category
#  6   TrafficDirection        138359 non-null  category
#  7   TrafficVolume           138359 non-null  float64
#  8   RadioMobileDataEnabled  138359 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 5.9 MB

# %%
RSRP_data.drop_duplicates(inplace=True)

# %%
RSRP_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2723541 entries, 0 to 2725352
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Timestamp               datetime64[ns, UTC]
#  1   LocationLatitude        float64
#  2   LocationLongitude       float64
#  3   RadioConnectionType     object
#  4   RadioNetworkGeneration  object
#  5   RadioOperatorName       object
#  6   RSRP                    int64
#  7   RadioMobileDataEnabled  object
#  8   DeviceManufacturer      object
#  9   DeviceName              object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(1), object(6)
# memory usage: 228.6+ MB

# %%
import sqlite3
cux = sqlite3.connect("telecom_data.db")

# %%
Traffic_Data_Grouped = pd.read_sql_query("SELECT * FROM Traffic_Data_Grouped", cux)

# %%
Traffic_Data_Grouped.info()

# %%
cols = [
       "RadioConnectionType",
       "RadioNetworkGeneration",
       "RadioOperatorName",
       "RadioMobileDataEnabled"
      ]

Traffic_Data_Grouped[cols] = Traffic_Data_Grouped[cols].astype('category')

# %%
Traffic_Data_Grouped.info()

# %%
Traffic_Data_Grouped["Timestamp"] = pd.to_datetime(Traffic_Data_Grouped["Timestamp"])

# %%
Traffic_Data_Grouped.info()

# %%
merged_data = pd.merge(RSRP_data,
                       Traffic_Data_Grouped,
                       how='inner',
                       on=["LocationLongitude", 
                            "LocationLatitude",
                            "RadioOperatorName", 
                            "RadioConnectionType", 
                            "RadioMobileDataEnabled", 
                            "RadioNetworkGeneration",
                           ]
                       )

# %%
merged_data.info()

# %%
merged_data = merged_data[
                            (merged_data["Timestamp_x"].dt.date ==  merged_data["Timestamp_y"].dt.date)
                               &
                            (merged_data["Timestamp_x"].dt.hour ==  merged_data["Timestamp_y"].dt.hour)
                               &
                            (merged_data["Timestamp_x"].dt.minute >= merged_data["Timestamp_y"].dt.minute)
                               &
                            (merged_data["Timestamp_y"].dt.minute > merged_data["Timestamp_x"].dt.minute -15)
                           ].copy()

# %%
merged_data.info()

# %%
merged_data["RadioConnectionType"] = merged_data["RadioConnectionType"].astype('category')
merged_data["DeviceName"] = merged_data["DeviceName"].astype('category')

# %%
merged_data.info()

# %%
merged_data.head(20)

# %%
merged_data_valid = merged_data[(merged_data["RSRP"] >= -144) & (merged_data["RSRP"] <= -40)]

# %%
merged_data_valid.head(20)

# %%
merged_data_valid["RadioNetworkGeneration"].value_counts()
