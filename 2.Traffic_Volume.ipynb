# %% [markdown]
# <span style="color:red">***This notebook should be run inside jupyter lab***</span>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandasql import sqldf

import panel as pn
pn.extension()
# the interactive plotting libs
import holoviews as hv
from holoviews.operation.datashader import inspect, rasterize
# colour maps lib
import colorcet as cc
# a lib for plotting a large dataset
import datashader as ds
# to convet the lat and lon to mercato web format
from datashader.utils import lnglat_to_meters
# %matplotlib inline
hv.extension('bokeh')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
traffic_data = pd.read_csv("TrafficVolume.csv")

# %%
traffic_data.head(10)
# Out:
#                        Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-02 00:45:00.000 +0300         24.636574          46.710026
# 1  2019-11-02 00:45:00.000 +0300         24.636124          46.711742
# 2  2019-11-02 00:00:00.000 +0300         24.636728          46.710230
# 3  2019-11-02 00:00:00.000 +0300         24.636705          46.710243
# 4  2019-11-02 02:00:00.000 +0300         24.718973          46.805927
# 5  2019-11-02 02:15:00.000 +0300         24.718742          46.806170
# 6  2019-11-02 01:45:00.000 +0300         24.718520          46.806080
# 7  2019-11-02 02:00:00.000 +0300         24.718939          46.806100
# 8  2019-11-02 02:30:00.000 +0300         24.718885          46.806026
# 9  2019-11-02 01:30:00.000 +0300         24.718520          46.806080
#
#   RadioConnectionType       Country RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile  Saudi Arabia                     3G        Operator A
# 1              Mobile  Saudi Arabia                     3G        Operator A
# 2              Mobile  Saudi Arabia                     3G        Operator A
# 3              Mobile  Saudi Arabia                     3G        Operator A
# 4              Mobile  Saudi Arabia                     4G        Operator B
# 5              Mobile  Saudi Arabia                     4G        Operator B
# 6              Mobile  Saudi Arabia                     4G        Operator B
# 7              Mobile  Saudi Arabia                     4G        Operator B
# 8              Mobile  Saudi Arabia                     4G        Operator B
# 9              Mobile  Saudi Arabia                     4G        Operator B
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      14.957630                Enabled
# 1           Uplink       0.304565                Enabled
# 2         Downlink      20.965813                Enabled
# 3           Uplink       0.706546                Enabled
# 4           Uplink       1.471874                Enabled
# 5           Uplink       2.128673                Enabled
# 6         Downlink     102.563844                Enabled
# 7         Downlink      54.727556                Enabled
# 8           Uplink       2.061129                Enabled
# 9           Uplink       0.830552                Enabled

# %%
traffic_data.sample(20)
# Out:
#                             Timestamp  LocationLatitude  LocationLongitude  \
# 43034   2019-11-02 13:45:00.000 +0300         24.718105          46.790546
# 39435   2019-11-02 20:00:00.000 +0300         24.623425          46.721000
# 78871   2019-11-03 20:00:00.000 +0300         24.563887          46.871117
# 130532  2019-11-04 14:00:00.000 +0300         24.692032          46.652460
# 50665   2019-11-02 16:45:00.000 +0300         24.626398          46.706318
# 51972   2019-11-03 06:15:00.000 +0300         24.594873          46.716026
# 67898   2019-11-03 21:30:00.000 +0300         24.835854          46.757310
# 87867   2019-11-04 14:45:00.000 +0300         24.773903          46.783700
# 111729  2019-11-04 21:45:00.000 +0300         24.789272          46.824223
# 102050  2019-11-03 05:15:00.000 +0300         24.823320          46.812910
# 41725   2019-11-02 10:15:00.000 +0300         24.708164          46.679250
# 61821   2019-11-02 15:30:00.000 +0300         24.810635          46.624340
# 100366  2019-11-04 23:00:00.000 +0300         24.960785          46.700203
# 111316  2019-11-04 20:30:00.000 +0300         24.569300          46.745056
# 88464   2019-11-03 19:30:00.000 +0300         24.589096          46.725420
# 53055   2019-11-03 03:15:00.000 +0300         24.676975          46.757350
# 72921   2019-11-04 08:45:00.000 +0300         24.738932          46.639270
# 138234  2019-11-02 08:15:00.000 +0300         24.686228          46.640130
# 24175   2019-11-03 07:30:00.000 +0300         24.702257          46.780420
# 57245   2019-11-02 23:30:00.000 +0300         24.774510          46.668938
#
#        RadioConnectionType       Country RadioNetworkGeneration  \
# 43034               Mobile  Saudi Arabia                     4G
# 39435               Mobile  Saudi Arabia                     3G
# 78871               Mobile  Saudi Arabia                     4G
# 130532              Mobile  Saudi Arabia                     4G
# 50665               Mobile  Saudi Arabia                     4G
# 51972               Mobile  Saudi Arabia                     4G
# 67898               Mobile  Saudi Arabia                     4G
# 87867               Mobile  Saudi Arabia                     4G
# 111729              Mobile  Saudi Arabia                     4G
# 102050              Mobile  Saudi Arabia                     4G
# 41725               Mobile  Saudi Arabia                     4G
# 61821               Mobile  Saudi Arabia                     4G
# 100366              Mobile  Saudi Arabia                     4G
# 111316              Mobile  Saudi Arabia                     3G
# 88464               Mobile  Saudi Arabia                     3G
# 53055               Mobile  Saudi Arabia                     4G
# 72921               Mobile  Saudi Arabia                     4G
# 138234              Mobile  Saudi Arabia                     4G
# 24175               Mobile  Saudi Arabia                     4G
# 57245               Mobile  Saudi Arabia                     4G
#
#        RadioOperatorName TrafficDirection  TrafficVolume  \
# 43034         Operator A         Downlink       0.117959
# 39435         Operator B         Downlink       0.104111
# 78871         Operator A           Uplink       0.046573
# 130532        Operator A           Uplink       0.296467
# 50665         Operator C           Uplink       0.065741
# 51972         Operator A         Downlink       0.152450
# 67898         Operator B           Uplink       1.491265
# 87867         Operator C         Downlink       2.325078
# 111729        Operator C         Downlink      51.641408
# 102050        Operator B           Uplink       0.011002
# 41725         Operator C           Uplink       0.022606
# 61821         Operator A         Downlink       0.098429
# 100366        Operator B         Downlink      28.138596
# 111316        Operator B         Downlink       0.299710
# 88464         Operator A           Uplink       0.038852
# 53055         Operator B           Uplink       0.447437
# 72921         Operator C         Downlink       0.018602
# 138234        Operator A         Downlink       1.832362
# 24175         Operator C         Downlink       0.027552
# 57245         Operator A         Downlink       0.187467
#
#        RadioMobileDataEnabled
# 43034                 Enabled
# 39435                 Enabled
# 78871                 Enabled
# 130532                Enabled
# 50665                 Enabled
# 51972                 Enabled
# 67898                 Enabled
# 87867                 Enabled
# 111729                Enabled
# 102050                Enabled
# 41725                 Enabled
# 61821                 Enabled
# 100366                Enabled
# 111316                Enabled
# 88464                 Enabled
# 53055                 Enabled
# 72921                 Enabled
# 138234                Enabled
# 24175                 Enabled
# 57245                 Enabled

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138469 entries, 0 to 138468
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138469 non-null  object
#  1   LocationLatitude        138469 non-null  float64
#  2   LocationLongitude       138469 non-null  float64
#  3   RadioConnectionType     138469 non-null  object
#  4   Country                 138469 non-null  object
#  5   RadioNetworkGeneration  138469 non-null  object
#  6   RadioOperatorName       138469 non-null  object
#  7   TrafficDirection        138469 non-null  object
#  8   TrafficVolume           138469 non-null  float64
#  9   RadioMobileDataEnabled  138469 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 10.6+ MB

# %% [markdown]
# This this we a relatively small dataset, compared to the other one, we have no nulls but some cleaning is required.
#
# let's look at the 'Country' column, seems all the values are Saudi Arabia

# %%
traffic_data["Country"].value_counts()
# Out:
# Saudi Arabia    138469
# Name: Country, dtype: int64

# %% [markdown]
# **Since There's only one value in this column, it should be removed since it does not contain much information.**

# %%
traffic_data.drop("Country", axis=1, inplace=True)

# %% [markdown]
# Looking at the *RadioConnectionType* Column

# %%
traffic_data["RadioConnectionType"].value_counts()
# Out:
# Mobile    136425
# WiFi        2044
# Name: RadioConnectionType, dtype: int64

# %% [markdown]
# **Now**, the *'Timestamp'* column must be converted to the datetime datatype in pandas. The *'to_datetime'* method is used with the format parameter provided, this helps in making the conversion process quick and more accurate. The formate of the datatime can be deduced from the dataset. Pandas provides a nice way to represent the time in way similar to regex.

# %%
# Now let's convert the TimeStamp column to datetime type in pandas, the 'utc' parameter is essential here for this to work!
traffic_data["Timestamp"] = pd.to_datetime(traffic_data["Timestamp"], format="%Y-%m-%d %H:%M:%S.%f%z", utc=True, errors='coerce')

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138469 entries, 0 to 138468
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138389 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138469 non-null  float64
#  2   LocationLongitude       138469 non-null  float64
#  3   RadioConnectionType     138469 non-null  object
#  4   RadioNetworkGeneration  138469 non-null  object
#  5   RadioOperatorName       138469 non-null  object
#  6   TrafficDirection        138469 non-null  object
#  7   TrafficVolume           138469 non-null  float64
#  8   RadioMobileDataEnabled  138469 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(3), object(5)
# memory usage: 9.5+ MB

# %%
traffic_data[traffic_data["Timestamp"].isna()]
# Out:
#        Timestamp  LocationLatitude  LocationLongitude RadioConnectionType  \
# 16163        NaT         24.587590          46.606747              Mobile
# 16164        NaT         24.587590          46.606747              Mobile
# 16165        NaT         24.587590          46.606747              Mobile
# 16166        NaT         24.587590          46.606747              Mobile
# 27281        NaT         24.580425          46.602528              Mobile
# ...          ...               ...                ...                 ...
# 138159       NaT         24.673980          46.687996              Mobile
# 138160       NaT         24.684572          46.729600              Mobile
# 138161       NaT         24.684572          46.729600              Mobile
# 138162       NaT         24.683254          46.699703              Mobile
# 138163       NaT         24.683254          46.699703              Mobile
#
#        RadioNetworkGeneration RadioOperatorName TrafficDirection  \
# 16163                      4G        Operator A         Downlink
# 16164                      4G        Operator A           Uplink
# 16165                      4G        Operator A         Downlink
# 16166                      4G        Operator A           Uplink
# 27281                      4G        Operator A           Uplink
# ...                       ...               ...              ...
# 138159                     3G        Operator B         Downlink
# 138160                     3G        Operator B           Uplink
# 138161                     3G        Operator B           Uplink
# 138162                     3G        Operator B         Downlink
# 138163                     3G        Operator B           Uplink
#
#         TrafficVolume RadioMobileDataEnabled
# 16163       21.853164                Enabled
# 16164        0.158825                Enabled
# 16165        2.571804                Enabled
# 16166        0.489610                Enabled
# 27281        0.463876                Enabled
# ...               ...                    ...
# 138159       0.157995                Enabled
# 138160       0.013140                Enabled
# 138161       0.148560                Enabled
# 138162       0.085103                Enabled
# 138163       0.050213                Enabled
#
# [80 rows x 9 columns]

# %% [markdown]
# We have around 80 datapoints cotaining invalid time formats, I'll drop these values

# %%
traffic_data.drop(traffic_data[traffic_data["Timestamp"].isna()].index, inplace=True)

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138389 entries, 0 to 138468
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138389 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138389 non-null  float64
#  2   LocationLongitude       138389 non-null  float64
#  3   RadioConnectionType     138389 non-null  object
#  4   RadioNetworkGeneration  138389 non-null  object
#  5   RadioOperatorName       138389 non-null  object
#  6   TrafficDirection        138389 non-null  object
#  7   TrafficVolume           138389 non-null  float64
#  8   RadioMobileDataEnabled  138389 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(3), object(5)
# memory usage: 10.6+ MB

# %% [markdown]
# Now let's check our numerical fields to check that they are in the valid range.
# - The valid range for latitude is between +90 and -90, any values outside this range are invalid

# %%
traffic_data[(traffic_data['LocationLatitude'] > 90) | (traffic_data['LocationLatitude'] < -90)].value_counts().sum()
# Out:
# 0

# %% [markdown]
# **All latitude values are valid!**

# %% [markdown]
# - The valid range for longitude is between +180 and -180, any values outside this range are invalid

# %%
traffic_data[(traffic_data['LocationLongitude'] > 180) | (traffic_data['LocationLongitude'] < -180)].value_counts().sum()
# Out:
# 0

# %% [markdown]
# **All longtitude values are valid!**

# %% [markdown]
# Now to save space and for more efficiency, let's convert the categorical columns to category type

# %%
cols = ["RadioConnectionType",
        "RadioNetworkGeneration",
        "RadioOperatorName",
        "RadioMobileDataEnabled",
        "TrafficDirection",
]

traffic_data[cols] = traffic_data[cols].astype('category')

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138389 entries, 0 to 138468
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138389 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138389 non-null  float64
#  2   LocationLongitude       138389 non-null  float64
#  3   RadioConnectionType     138389 non-null  category
#  4   RadioNetworkGeneration  138389 non-null  category
#  5   RadioOperatorName       138389 non-null  category
#  6   TrafficDirection        138389 non-null  category
#  7   TrafficVolume           138389 non-null  float64
#  8   RadioMobileDataEnabled  138389 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 5.9 MB

# %% [markdown]
# **This is much cleaner!**

# %% [markdown]
# Now, I'll sort the data according to time

# %%
# Don't use the 'TimeStamp' as an index because there are duplicates!
traffic_data_time_sorted = traffic_data.sort_values(by=["Timestamp","LocationLatitude", "LocationLongitude", "RadioOperatorName", "RadioNetworkGeneration", "TrafficDirection"], ignore_index=True)
traffic_data_time_sorted.head(10)
# Out:
#                   Timestamp  LocationLatitude  LocationLongitude  \
# 0 2019-11-01 18:00:00+00:00         24.639288          46.728962
# 1 2019-11-01 18:00:00+00:00         24.639288          46.728962
# 2 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 3 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 4 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 5 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 6 2019-11-01 18:30:00+00:00         24.626589          46.689250
# 7 2019-11-01 18:30:00+00:00         24.626589          46.689250
# 8 2019-11-01 18:30:00+00:00         24.626589          46.689250
# 9 2019-11-01 18:30:00+00:00         24.626589          46.689250
#
#   RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile                     4G        Operator B
# 1              Mobile                     4G        Operator B
# 2              Mobile                     3G        Operator B
# 3              Mobile                     3G        Operator B
# 4              Mobile                     4G        Operator B
# 5              Mobile                     4G        Operator B
# 6              Mobile                     4G        Operator C
# 7              Mobile                     4G        Operator C
# 8              Mobile                     4G        Operator C
# 9              Mobile                     4G        Operator C
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      45.701516                Enabled
# 1           Uplink       1.740874                Enabled
# 2         Downlink       5.182752                Enabled
# 3           Uplink       0.390352                Enabled
# 4         Downlink      30.303686                Enabled
# 5           Uplink       1.083652                Enabled
# 6         Downlink       0.005951                Enabled
# 7         Downlink       2.263094                Enabled
# 8           Uplink       1.889517                Enabled
# 9           Uplink       0.011245                Enabled

# %% [markdown]
# We can see some duplicates here in the head of the dataframe, all the fields are the same except for the Traffic Volume. I'll use the pandasql to take he average of the traffic volume in these duplicate rows

# %%
query = """
SELECT Timestamp, LocationLatitude, LocationLongitude, RadioConnectionType, RadioNetworkGeneration, RadioOperatorName, TrafficDirection, SUM(TrafficVolume) AS TrafficVolume, RadioMobileDataEnabled
FROM traffic_data
GROUP BY Timestamp, LocationLatitude, LocationLongitude, RadioConnectionType, RadioNetworkGeneration, RadioOperatorName, TrafficDirection, RadioMobileDataEnabled
"""
traffic_data_grouped = sqldf(query)

# %%
traffic_data_grouped.head(10)
# Out:
#                     Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-01 18:00:00.000000         24.639288          46.728962
# 1  2019-11-01 18:00:00.000000         24.639288          46.728962
# 2  2019-11-01 18:15:00.000000         24.639288          46.728962
# 3  2019-11-01 18:15:00.000000         24.639288          46.728962
# 4  2019-11-01 18:15:00.000000         24.639288          46.728962
# 5  2019-11-01 18:15:00.000000         24.639288          46.728962
# 6  2019-11-01 18:30:00.000000         24.626589          46.689250
# 7  2019-11-01 18:30:00.000000         24.626589          46.689250
# 8  2019-11-01 18:30:00.000000         24.639288          46.728962
# 9  2019-11-01 18:30:00.000000         24.639288          46.728962
#
#   RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile                     4G        Operator B
# 1              Mobile                     4G        Operator B
# 2              Mobile                     3G        Operator B
# 3              Mobile                     3G        Operator B
# 4              Mobile                     4G        Operator B
# 5              Mobile                     4G        Operator B
# 6              Mobile                     4G        Operator C
# 7              Mobile                     4G        Operator C
# 8              Mobile                     4G        Operator B
# 9              Mobile                     4G        Operator B
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      45.701516                Enabled
# 1           Uplink       1.740874                Enabled
# 2         Downlink       5.182752                Enabled
# 3           Uplink       0.390352                Enabled
# 4         Downlink      30.303686                Enabled
# 5           Uplink       1.083652                Enabled
# 6         Downlink       2.269045                Enabled
# 7           Uplink       1.900762                Enabled
# 8         Downlink       0.056850                Enabled
# 9           Uplink       0.069332                Enabled

# %%
traffic_data_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138067 entries, 0 to 138066
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138067 non-null  object
#  1   LocationLatitude        138067 non-null  float64
#  2   LocationLongitude       138067 non-null  float64
#  3   RadioConnectionType     138067 non-null  object
#  4   RadioNetworkGeneration  138067 non-null  object
#  5   RadioOperatorName       138067 non-null  object
#  6   TrafficDirection        138067 non-null  object
#  7   TrafficVolume           138067 non-null  float64
#  8   RadioMobileDataEnabled  138067 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 9.5+ MB

# %%
Downlink_mask = traffic_data_grouped.TrafficDirection=="Downlink"
Downlink_df = traffic_data_grouped[Downlink_mask]

Uplink_mask = traffic_data_grouped.TrafficDirection=="Uplink"
Uplink_df = traffic_data_grouped[Uplink_mask]

# %%
print(Uplink_df.shape)
print(Downlink_df.shape)
# Out:
# (69007, 9)
# (69060, 9)

# %%
Uplink_df.head(10)
# Out:
#                      Timestamp  LocationLatitude  LocationLongitude  \
# 1   2019-11-01 18:00:00.000000         24.639288          46.728962
# 3   2019-11-01 18:15:00.000000         24.639288          46.728962
# 5   2019-11-01 18:15:00.000000         24.639288          46.728962
# 7   2019-11-01 18:30:00.000000         24.626589          46.689250
# 9   2019-11-01 18:30:00.000000         24.639288          46.728962
# 11  2019-11-01 18:45:00.000000         24.626589          46.689250
# 13  2019-11-01 18:45:00.000000         24.641806          46.715973
# 15  2019-11-01 19:00:00.000000         24.619022          46.721550
# 17  2019-11-01 19:00:00.000000         24.626589          46.689250
# 19  2019-11-01 19:15:00.000000         24.619022          46.721550
#
#    RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 1               Mobile                     4G        Operator B
# 3               Mobile                     3G        Operator B
# 5               Mobile                     4G        Operator B
# 7               Mobile                     4G        Operator C
# 9               Mobile                     4G        Operator B
# 11              Mobile                     4G        Operator C
# 13              Mobile                     4G        Operator B
# 15              Mobile                     4G        Operator B
# 17              Mobile                     4G        Operator C
# 19              Mobile                     4G        Operator B
#
#    TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 1            Uplink       1.740874                Enabled
# 3            Uplink       0.390352                Enabled
# 5            Uplink       1.083652                Enabled
# 7            Uplink       1.900762                Enabled
# 9            Uplink       0.069332                Enabled
# 11           Uplink       2.470590                Enabled
# 13           Uplink       0.337878                Enabled
# 15           Uplink       0.133907                Enabled
# 17           Uplink       2.151763                Enabled
# 19           Uplink       0.482521                Enabled

# %%
Uplink_df.sample(20)
# Out:
#                          Timestamp  LocationLatitude  LocationLongitude  \
# 69661   2019-11-03 12:15:00.000000         24.726952          46.842728
# 82234   2019-11-03 16:45:00.000000         24.601580          46.623966
# 13959   2019-11-02 08:30:00.000000         24.568752          46.765495
# 130432  2019-11-04 17:30:00.000000         24.829891          46.636290
# 113318  2019-11-04 11:15:00.000000         24.795113          46.729046
# 97730   2019-11-04 03:30:00.000000         24.742900          46.588097
# 128589  2019-11-04 17:00:00.000000         24.640230          46.721910
# 16736   2019-11-02 09:30:00.000000         24.729185          46.718693
# 53505   2019-11-03 05:15:00.000000         24.628407          46.744556
# 107486  2019-11-04 09:00:00.000000         24.628063          46.711525
# 706     2019-11-01 21:15:00.000000         24.799650          46.770690
# 89857   2019-11-03 19:30:00.000000         24.719276          46.604470
# 105750  2019-11-04 08:15:00.000000         24.569992          46.701090
# 49077   2019-11-03 00:15:00.000000         24.683535          46.780800
# 45542   2019-11-02 20:30:00.000000         24.775337          46.733974
# 26696   2019-11-02 13:15:00.000000         24.943785          46.986130
# 84110   2019-11-03 17:15:00.000000         24.746960          46.650986
# 87108   2019-11-03 18:30:00.000000         24.552229          46.619667
# 113891  2019-11-04 11:30:00.000000         24.756756          46.766610
# 136428  2019-11-04 20:00:00.000000         24.716946          46.852370
#
#        RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 69661               Mobile                     4G        Operator C
# 82234               Mobile                     3G        Operator A
# 13959               Mobile                     3G        Operator A
# 130432              Mobile                     3G        Operator A
# 113318              Mobile                     4G        Operator A
# 97730               Mobile                     3G        Operator B
# 128589              Mobile                     4G        Operator B
# 16736               Mobile                     4G        Operator A
# 53505                 WiFi                     4G        Operator A
# 107486              Mobile                     4G        Operator A
# 706                 Mobile                     3G        Operator C
# 89857               Mobile                     3G        Operator A
# 105750              Mobile                     4G        Operator A
# 49077               Mobile                     4G        Operator C
# 45542               Mobile                     4G        Operator A
# 26696               Mobile                     4G        Operator A
# 84110               Mobile                     4G        Operator A
# 87108               Mobile                     4G        Operator A
# 113891              Mobile                     4G        Operator C
# 136428              Mobile                     4G        Operator A
#
#        TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 69661            Uplink       0.013501                Enabled
# 82234            Uplink       0.203075                Enabled
# 13959            Uplink       0.271426                Enabled
# 130432           Uplink      19.712431                Enabled
# 113318           Uplink       0.044725                Enabled
# 97730            Uplink       0.658399                Enabled
# 128589           Uplink       0.636208                Enabled
# 16736            Uplink       0.080812                Enabled
# 53505            Uplink       0.705836                Enabled
# 107486           Uplink       0.137575                Enabled
# 706              Uplink       0.170591                Enabled
# 89857            Uplink       0.419644                Enabled
# 105750           Uplink       0.758742                Enabled
# 49077            Uplink       0.937469                Enabled
# 45542            Uplink       1.328927                Enabled
# 26696            Uplink       0.273334                Enabled
# 84110            Uplink       0.067401                Enabled
# 87108            Uplink       0.900057                Enabled
# 113891           Uplink       0.775912                Enabled
# 136428           Uplink       0.025656                Enabled

# %%
Downlink_df.head(10)
# Out:
#                      Timestamp  LocationLatitude  LocationLongitude  \
# 0   2019-11-01 18:00:00.000000         24.639288          46.728962
# 2   2019-11-01 18:15:00.000000         24.639288          46.728962
# 4   2019-11-01 18:15:00.000000         24.639288          46.728962
# 6   2019-11-01 18:30:00.000000         24.626589          46.689250
# 8   2019-11-01 18:30:00.000000         24.639288          46.728962
# 10  2019-11-01 18:45:00.000000         24.626589          46.689250
# 12  2019-11-01 18:45:00.000000         24.640503          46.716290
# 14  2019-11-01 19:00:00.000000         24.619022          46.721550
# 16  2019-11-01 19:00:00.000000         24.626589          46.689250
# 18  2019-11-01 19:15:00.000000         24.619022          46.721550
#
#    RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0               Mobile                     4G        Operator B
# 2               Mobile                     3G        Operator B
# 4               Mobile                     4G        Operator B
# 6               Mobile                     4G        Operator C
# 8               Mobile                     4G        Operator B
# 10              Mobile                     4G        Operator C
# 12              Mobile                     4G        Operator B
# 14              Mobile                     4G        Operator B
# 16              Mobile                     4G        Operator C
# 18              Mobile                     4G        Operator B
#
#    TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0          Downlink      45.701516                Enabled
# 2          Downlink       5.182752                Enabled
# 4          Downlink      30.303686                Enabled
# 6          Downlink       2.269045                Enabled
# 8          Downlink       0.056850                Enabled
# 10         Downlink       2.743515                Enabled
# 12         Downlink       8.589538                Enabled
# 14         Downlink       0.331708                Enabled
# 16         Downlink       2.475489                Enabled
# 18         Downlink       1.351583                Enabled

# %%
Downlink_df.sample(20)
# Out:
#                          Timestamp  LocationLatitude  LocationLongitude  \
# 20983   2019-11-02 11:15:00.000000         24.605938          46.690605
# 32303   2019-11-02 15:15:00.000000         24.752024          46.857580
# 107796  2019-11-04 09:00:00.000000         24.784561          46.796062
# 9491    2019-11-02 06:15:00.000000         24.752796          46.620720
# 11228   2019-11-02 07:15:00.000000         24.562157          46.765087
# 42816   2019-11-02 19:15:00.000000         24.603045          46.728462
# 103452  2019-11-04 07:00:00.000000         24.762293          46.672665
# 69708   2019-11-03 12:15:00.000000         24.750473          46.656944
# 9965    2019-11-02 06:30:00.000000         24.720785          46.824295
# 9677    2019-11-02 06:30:00.000000         24.551900          46.684610
# 125612  2019-11-04 16:00:00.000000         24.572323          46.580370
# 111695  2019-11-04 10:45:00.000000         24.617245          46.531460
# 129767  2019-11-04 17:15:00.000000         25.034151          46.676420
# 104791  2019-11-04 07:45:00.000000         24.626913          46.838150
# 5217    2019-11-02 03:45:00.000000         24.577858          46.881954
# 66733   2019-11-03 11:00:00.000000         24.800720          46.673970
# 69936   2019-11-03 12:30:00.000000         24.571619          46.620270
# 80734   2019-11-03 16:15:00.000000         24.569735          46.833637
# 136944  2019-11-04 20:15:00.000000         24.722261          46.665253
# 137670  2019-11-04 20:45:00.000000         24.588373          46.618553
#
#        RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 20983               Mobile                     3G        Operator A
# 32303               Mobile                     4G        Operator A
# 107796              Mobile                     3G        Operator B
# 9491                Mobile                     4G        Operator A
# 11228               Mobile                     4G        Operator A
# 42816               Mobile                     3G        Operator C
# 103452              Mobile                     4G        Operator B
# 69708               Mobile                     4G        Operator B
# 9965                Mobile                     4G        Operator C
# 9677                Mobile                     4G        Operator B
# 125612              Mobile                     4G        Operator A
# 111695              Mobile                     3G        Operator C
# 129767              Mobile                     4G        Operator C
# 104791              Mobile                     4G        Operator B
# 5217                Mobile                     4G        Operator A
# 66733               Mobile                     4G        Operator A
# 69936               Mobile                     4G        Operator A
# 80734               Mobile                     4G        Operator B
# 136944              Mobile                     4G        Operator A
# 137670              Mobile                     4G        Operator B
#
#        TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 20983          Downlink       8.861309                Enabled
# 32303          Downlink      17.108458                Enabled
# 107796         Downlink       0.015100                Enabled
# 9491           Downlink       0.957312                Enabled
# 11228          Downlink       0.070468                Enabled
# 42816          Downlink       0.051280                Enabled
# 103452         Downlink       0.024587                Enabled
# 69708          Downlink       2.011485                Enabled
# 9965           Downlink      59.612528                Enabled
# 9677           Downlink      15.974722                Enabled
# 125612         Downlink       0.034110                Enabled
# 111695         Downlink       0.092620                Enabled
# 129767         Downlink      18.489706                Enabled
# 104791         Downlink      42.116745                Enabled
# 5217           Downlink       1.149661                Enabled
# 66733          Downlink       1.310685                Enabled
# 69936          Downlink       0.659879                Enabled
# 80734          Downlink       0.106161                Enabled
# 136944         Downlink       2.307451                Enabled
# 137670         Downlink       0.008438                Enabled

# %%
Uplink_df.describe().transpose()
# Out:
#                      count       mean        std        min        25%  \
# LocationLatitude   69007.0  24.689345   0.096779  24.435455  24.614894
# LocationLongitude  69007.0  46.726149   0.090212  46.358420  46.668570
# TrafficVolume      69007.0   3.235700  93.767577   0.001240   0.107215
#
#                          50%        75%          max
# LocationLatitude   24.685047  24.759370    25.034151
# LocationLongitude  46.719044  46.787045    47.180748
# TrafficVolume       0.327091   1.017883  8439.682444

# %%
Downlink_df.describe().transpose()
# Out:
#                      count       mean          std        min        25%  \
# LocationLatitude   69060.0  24.689421     0.096643  24.435455  24.615019
# LocationLongitude  69060.0  46.726108     0.090075  46.358420  46.668563
# TrafficVolume      69060.0  44.419884  1512.255292   0.001060   0.249153
#
#                          50%        75%            max
# LocationLatitude   24.685434  24.759370      25.034151
# LocationLongitude  46.719149  46.786918      47.180748
# TrafficVolume       1.365706  10.901087  104022.000000

# %%
df = Downlink_df.copy()

# This step is needed to prepare the data to be plotted on the map
df["LocationLongitude"], df["LocationLatitude"] = lnglat_to_meters(df["LocationLongitude"], df["LocationLatitude"])

# %%
# Index must be resetted before plotting
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#                     Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-01 18:00:00.000000      2.831504e+06       5.201844e+06
# 1  2019-11-01 18:15:00.000000      2.831504e+06       5.201844e+06
# 2  2019-11-01 18:15:00.000000      2.831504e+06       5.201844e+06
# 3  2019-11-01 18:30:00.000000      2.829949e+06       5.197424e+06
# 4  2019-11-01 18:30:00.000000      2.831504e+06       5.201844e+06
#
#   RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile                     4G        Operator B
# 1              Mobile                     3G        Operator B
# 2              Mobile                     4G        Operator B
# 3              Mobile                     4G        Operator C
# 4              Mobile                     4G        Operator B
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      45.701516                Enabled
# 1         Downlink       5.182752                Enabled
# 2         Downlink      30.303686                Enabled
# 3         Downlink       2.269045                Enabled
# 4         Downlink       0.056850                Enabled

# %%
esri = hv.element.tiles.ESRI().redim(x="Longtitude", y="Latitude").opts(alpha=0.2, width=1000, height=700, bgcolor='black')
COLORS = {"Operator A": cc.kr, "Operator B": cc.kg, "Operator C": cc.kb}

def traffic_map(operator_name):
    df_operator = df[df["RadioOperatorName"] == operator_name].copy()
    # return df_operator.plot.hexbin(x="LocationLongitude", y="LocationLatitude", C="TrafficVolume", reduce_C_function=np.sum, cmap="viridis", figsize=(15,15))
    if (len(df_operator) == 0 ):
        return esri
    operator_tiles =  hv.element.HexTiles(df_operator, kdims=["LocationLongitude", "LocationLatitude"])
    # operator_points.groupby(kdims=["LocationLongitude", "LocationLatitude"])
    # operator_points.aggregate(dimensions="TrafficVolume", function=np.sum)
    operator_tiles.opts(cmap=COLORS[operator_name], alpha=0.8, cnorm="linear", tools=["hover"], width=1000, height=700, scale=(hv.dim('Count').norm()*0.5)+0.5)
    # rastered = rasterize(operator_points).opts(cmap=COLORS[operator_name], cnorm="eq_hist",  width=1000, height=700)
    # operator_highlight = inspect(rastered).opts(marker="o", size=10, fill_alpha=0, color='white', tools=["hover"])
    return esri * operator_tiles
    
operator_select = pn.widgets.RadioButtonGroup(options=list(COLORS.keys()))
interactive = pn.bind(traffic_map, operator_select)
first_app = pn.Column(operator_select, interactive)
first_app
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'b9aa3d9c-be86-45bb-b773-b495ebd4c442': {'defs': …

# %%
def operator_map(operator_name):
    df_operator = df[df["RadioOperatorName"] == operator_name].copy()
    # df_operator["TrafficVolume"] = df_operator["TrafficVolume"] / np.linalg.norm(df_operator["TrafficVolume"]) * 500
    print(len(df_operator))
    plt.figure(figsize=(18, 18))
    # return  df_operator.plot.hexbin(
    #                                 x="LocationLongitude", 
    #                                 y="LocationLatitude", 
    #                                 C="TrafficVolume",
    #                                 reduce_C_function=np.sum, 
    #                                 cmap="viridis",
    #                                 sizes= [1,3,7,10,50],
    #                                 figsize=(20,15)
    #                                 )
    hex_plot = plt.hexbin(
                        data=df_operator,
                        x="LocationLongitude", 
                        y="LocationLatitude", 
                        C="TrafficVolume",
                        reduce_C_function=np.sum, 
                        cmap="viridis",
                        sizes= [1,3,7,10,50],
                        # figsize=(20,15)
                        )
    colors = pd.Series(hex_plot.get_array())
    data =df_operator["TrafficVolume"]
    output = pd.DataFrame(data={"colors":colors, "data":data}, index=data.index)
    output.to_csv("output.csv")
    print(len(hex_plot.get_sizes()))
operator_select = pn.widgets.RadioButtonGroup(options=list(COLORS.keys()))
interactive = pn.bind(operator_map, operator_select)
first_app = pn.Column(operator_select, interactive)
first_app
# Out:
# 34043
# 5
# BokehModel(combine_events=True, render_bundle={'docs_json': {'a750ba47-3f03-4c07-bd04-a1f1f5c3e1f3': {'defs': …
