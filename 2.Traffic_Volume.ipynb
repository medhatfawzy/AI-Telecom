# %% [markdown]
# <span style="color:red">***This notebook should be run inside jupyter lab***</span>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandasql import sqldf

import panel as pn
pn.extension()
# the interactive plotting libs
import holoviews as hv
from holoviews.operation.datashader import inspect, rasterize
# colour maps lib
import colorcet as cc
# a lib for plotting a large dataset
import datashader as ds
# to convet the lat and lon to mercato web format
from datashader.utils import lnglat_to_meters
# %matplotlib inline
hv.extension('bokeh')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# # Reading Data
# First I'll read the raw dataset from the csv file.

# %%
traffic_data = pd.read_csv("TrafficVolume.csv")

# %% [markdown]
# # EDA
# I'll perfome some EDA on the data

# %%
traffic_data.head(10)
# Out:
#                        Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-02 00:45:00.000 +0300         24.636574          46.710026
# 1  2019-11-02 00:45:00.000 +0300         24.636124          46.711742
# 2  2019-11-02 00:00:00.000 +0300         24.636728          46.710230
# 3  2019-11-02 00:00:00.000 +0300         24.636705          46.710243
# 4  2019-11-02 02:00:00.000 +0300         24.718973          46.805927
# 5  2019-11-02 02:15:00.000 +0300         24.718742          46.806170
# 6  2019-11-02 01:45:00.000 +0300         24.718520          46.806080
# 7  2019-11-02 02:00:00.000 +0300         24.718939          46.806100
# 8  2019-11-02 02:30:00.000 +0300         24.718885          46.806026
# 9  2019-11-02 01:30:00.000 +0300         24.718520          46.806080
#
#   RadioConnectionType       Country RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile  Saudi Arabia                     3G        Operator A
# 1              Mobile  Saudi Arabia                     3G        Operator A
# 2              Mobile  Saudi Arabia                     3G        Operator A
# 3              Mobile  Saudi Arabia                     3G        Operator A
# 4              Mobile  Saudi Arabia                     4G        Operator B
# 5              Mobile  Saudi Arabia                     4G        Operator B
# 6              Mobile  Saudi Arabia                     4G        Operator B
# 7              Mobile  Saudi Arabia                     4G        Operator B
# 8              Mobile  Saudi Arabia                     4G        Operator B
# 9              Mobile  Saudi Arabia                     4G        Operator B
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      14.957630                Enabled
# 1           Uplink       0.304565                Enabled
# 2         Downlink      20.965813                Enabled
# 3           Uplink       0.706546                Enabled
# 4           Uplink       1.471874                Enabled
# 5           Uplink       2.128673                Enabled
# 6         Downlink     102.563844                Enabled
# 7         Downlink      54.727556                Enabled
# 8           Uplink       2.061129                Enabled
# 9           Uplink       0.830552                Enabled

# %%
traffic_data.sample(20)
# Out:
#                             Timestamp  LocationLatitude  LocationLongitude  \
# 26989   2019-11-02 13:45:00.000 +0300         24.756756          46.746770
# 98478   2019-11-04 10:30:00.000 +0300         24.873793          46.807880
# 90681   2019-11-03 08:45:00.000 +0300         24.678331          46.802660
# 131751  2019-11-04 17:15:00.000 +0300         24.888397          46.622470
# 102195  2019-11-03 22:00:00.000 +0300         24.716946          46.852370
# 59712   2019-11-03 17:30:00.000 +0300         24.686104          46.821384
# 70830   2019-11-04 15:45:00.000 +0300         24.744820          46.811440
# 53332   2019-11-03 15:15:00.000 +0300         24.472044          46.970340
# 106549  2019-11-03 09:30:00.000 +0300         24.528961          46.939384
# 58012   2019-11-02 18:45:00.000 +0300         24.642864          46.728218
# 45877   2019-11-02 20:15:00.000 +0300         24.564780          46.755070
# 9804    2019-11-02 15:00:00.000 +0300         24.653065          46.792637
# 38629   2019-11-02 18:45:00.000 +0300         24.843008          46.792812
# 75314   2019-11-03 21:15:00.000 +0300         24.643970          46.726940
# 100992  2019-11-04 12:00:00.000 +0300         24.631918          46.872196
# 112173  2019-11-04 19:30:00.000 +0300         24.588749          46.720924
# 94038   2019-11-04 15:15:00.000 +0300         24.541012          46.896950
# 37456   2019-11-03 11:00:00.000 +0300         24.767670          46.821700
# 97899   2019-11-04 19:45:00.000 +0300         24.696722          46.779648
# 64520   2019-11-03 15:30:00.000 +0300         24.519646          46.935910
#
#        RadioConnectionType       Country RadioNetworkGeneration  \
# 26989               Mobile  Saudi Arabia                     4G
# 98478               Mobile  Saudi Arabia                     4G
# 90681               Mobile  Saudi Arabia                     4G
# 131751              Mobile  Saudi Arabia                     3G
# 102195              Mobile  Saudi Arabia                     4G
# 59712               Mobile  Saudi Arabia                     3G
# 70830               Mobile  Saudi Arabia                     4G
# 53332               Mobile  Saudi Arabia                     4G
# 106549              Mobile  Saudi Arabia                     4G
# 58012               Mobile  Saudi Arabia                     4G
# 45877               Mobile  Saudi Arabia                     4G
# 9804                Mobile  Saudi Arabia                     4G
# 38629               Mobile  Saudi Arabia                     4G
# 75314               Mobile  Saudi Arabia                     4G
# 100992              Mobile  Saudi Arabia                     4G
# 112173              Mobile  Saudi Arabia                     4G
# 94038               Mobile  Saudi Arabia                     4G
# 37456               Mobile  Saudi Arabia                     4G
# 97899               Mobile  Saudi Arabia                     3G
# 64520               Mobile  Saudi Arabia                     4G
#
#        RadioOperatorName TrafficDirection  TrafficVolume  \
# 26989         Operator C         Downlink      12.108063
# 98478         Operator B           Uplink       0.057715
# 90681         Operator A         Downlink      22.958351
# 131751        Operator A           Uplink       0.108436
# 102195        Operator A         Downlink       0.454403
# 59712         Operator B           Uplink       0.448669
# 70830         Operator C         Downlink      39.139370
# 53332         Operator A           Uplink       0.303382
# 106549        Operator B         Downlink       0.283988
# 58012         Operator A           Uplink       0.026628
# 45877         Operator C           Uplink       0.243389
# 9804          Operator A         Downlink       1.195574
# 38629         Operator A           Uplink       0.153651
# 75314         Operator B           Uplink       0.205423
# 100992        Operator C         Downlink      18.863415
# 112173        Operator C           Uplink       3.846776
# 94038         Operator A         Downlink      44.982204
# 37456         Operator A           Uplink       0.006101
# 97899         Operator B         Downlink       1.485992
# 64520         Operator C         Downlink       1.029106
#
#        RadioMobileDataEnabled
# 26989                 Enabled
# 98478                 Enabled
# 90681                 Enabled
# 131751                Enabled
# 102195                Enabled
# 59712                 Enabled
# 70830                 Enabled
# 53332                 Enabled
# 106549                Enabled
# 58012                 Enabled
# 45877                 Enabled
# 9804                  Enabled
# 38629                 Enabled
# 75314                 Enabled
# 100992                Enabled
# 112173                Enabled
# 94038                 Enabled
# 37456                 Enabled
# 97899                 Enabled
# 64520                 Enabled

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138469 entries, 0 to 138468
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138469 non-null  object
#  1   LocationLatitude        138469 non-null  float64
#  2   LocationLongitude       138469 non-null  float64
#  3   RadioConnectionType     138469 non-null  object
#  4   Country                 138469 non-null  object
#  5   RadioNetworkGeneration  138469 non-null  object
#  6   RadioOperatorName       138469 non-null  object
#  7   TrafficDirection        138469 non-null  object
#  8   TrafficVolume           138469 non-null  float64
#  9   RadioMobileDataEnabled  138469 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 10.6+ MB

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# This is a relatively small dataset, compared to the other one, there is no nulls but some cleaning is required.

# %% [markdown]
# Now to save space and for more efficiency, let's convert the categorical columns to category type

# %%
cols = ["RadioConnectionType",
        "RadioNetworkGeneration",
        "RadioOperatorName",
        "RadioMobileDataEnabled",
        "TrafficDirection",
       ]

traffic_data[cols] = traffic_data[cols].astype('category')

# %% [markdown]
# Looking at the 'Country' column, seems all the values are 'Saudi Arabia'.

# %%
traffic_data["Country"].value_counts()
# Out:
# Saudi Arabia    138469
# Name: Country, dtype: int64

# %% [markdown]
# **Since There's only one value in this column, it should be removed since it does not contain any information gain.**

# %%
traffic_data.drop("Country", axis=1, inplace=True)

# %% [markdown]
# I'll look at the *RadioConnectionType* Column as well.

# %%
traffic_data["RadioConnectionType"].value_counts()
# Out:
# Mobile    136425
# WiFi        2044
# Name: RadioConnectionType, dtype: int64

# %% [markdown]
# There is a dominating class, but there are two values not a one like with the previous column, so I'll leave it.

# %% [markdown]
# **Now**, the *'Timestamp'* column must be converted to the datetime datatype in pandas. The *'to_datetime'* method is used with the format parameter provided, this helps in making the conversion process quick and more accurate. The format of the datatime can be deduced from the dataset. Pandas provides a nice way to represent the time in way similar to regex.

# %%
# Now let's convert the TimeStamp column to datetime type in pandas, 
# the 'utc' parameter is essential here for this to work
# and we have to use errors = coerce as well since there is some bad values inside this column
traffic_data["Timestamp"] = pd.to_datetime(traffic_data["Timestamp"], format="%Y-%m-%d %H:%M:%S.%f%z", utc=True, errors='coerce')

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138469 entries, 0 to 138468
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138389 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138469 non-null  float64
#  2   LocationLongitude       138469 non-null  float64
#  3   RadioConnectionType     138469 non-null  category
#  4   RadioNetworkGeneration  138469 non-null  category
#  5   RadioOperatorName       138469 non-null  category
#  6   TrafficDirection        138469 non-null  category
#  7   TrafficVolume           138469 non-null  float64
#  8   RadioMobileDataEnabled  138469 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 4.9 MB

# %%
traffic_data[traffic_data["Timestamp"].isna()]
# Out:
#        Timestamp  LocationLatitude  LocationLongitude RadioConnectionType  \
# 16163        NaT         24.587590          46.606747              Mobile
# 16164        NaT         24.587590          46.606747              Mobile
# 16165        NaT         24.587590          46.606747              Mobile
# 16166        NaT         24.587590          46.606747              Mobile
# 27281        NaT         24.580425          46.602528              Mobile
# ...          ...               ...                ...                 ...
# 138159       NaT         24.673980          46.687996              Mobile
# 138160       NaT         24.684572          46.729600              Mobile
# 138161       NaT         24.684572          46.729600              Mobile
# 138162       NaT         24.683254          46.699703              Mobile
# 138163       NaT         24.683254          46.699703              Mobile
#
#        RadioNetworkGeneration RadioOperatorName TrafficDirection  \
# 16163                      4G        Operator A         Downlink
# 16164                      4G        Operator A           Uplink
# 16165                      4G        Operator A         Downlink
# 16166                      4G        Operator A           Uplink
# 27281                      4G        Operator A           Uplink
# ...                       ...               ...              ...
# 138159                     3G        Operator B         Downlink
# 138160                     3G        Operator B           Uplink
# 138161                     3G        Operator B           Uplink
# 138162                     3G        Operator B         Downlink
# 138163                     3G        Operator B           Uplink
#
#         TrafficVolume RadioMobileDataEnabled
# 16163       21.853164                Enabled
# 16164        0.158825                Enabled
# 16165        2.571804                Enabled
# 16166        0.489610                Enabled
# 27281        0.463876                Enabled
# ...               ...                    ...
# 138159       0.157995                Enabled
# 138160       0.013140                Enabled
# 138161       0.148560                Enabled
# 138162       0.085103                Enabled
# 138163       0.050213                Enabled
#
# [80 rows x 9 columns]

# %% [markdown]
# We have around 80 datapoints cotaining invalid time formats, I'll drop these values

# %%
traffic_data.drop(traffic_data[traffic_data["Timestamp"].isna()].index, inplace=True)

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138389 entries, 0 to 138468
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138389 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138389 non-null  float64
#  2   LocationLongitude       138389 non-null  float64
#  3   RadioConnectionType     138389 non-null  category
#  4   RadioNetworkGeneration  138389 non-null  category
#  5   RadioOperatorName       138389 non-null  category
#  6   TrafficDirection        138389 non-null  category
#  7   TrafficVolume           138389 non-null  float64
#  8   RadioMobileDataEnabled  138389 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 5.9 MB

# %% [markdown]
# Now let's check our numerical fields to check that they are in the valid range.
# - The valid range for latitude is between +90 and -90, any values outside this range are invalid

# %%
traffic_data[(traffic_data['LocationLatitude'] > 90) | (traffic_data['LocationLatitude'] < -90)].value_counts().sum()
# Out:
# 0

# %% [markdown]
# **All latitude values are valid!**

# %% [markdown]
# - The valid range for longitude is between +180 and -180, any values outside this range are invalid

# %%
traffic_data[(traffic_data['LocationLongitude'] > 180) | (traffic_data['LocationLongitude'] < -180)].value_counts().sum()
# Out:
# 0

# %% [markdown]
# **All longtitude values are valid!**

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138389 entries, 0 to 138468
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138389 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138389 non-null  float64
#  2   LocationLongitude       138389 non-null  float64
#  3   RadioConnectionType     138389 non-null  category
#  4   RadioNetworkGeneration  138389 non-null  category
#  5   RadioOperatorName       138389 non-null  category
#  6   TrafficDirection        138389 non-null  category
#  7   TrafficVolume           138389 non-null  float64
#  8   RadioMobileDataEnabled  138389 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 5.9 MB

# %% [markdown]
# **This is much cleaner!**

# %% [markdown]
# Now, I'll sort the data according to time

# %%
# Don't use the 'TimeStamp' as an index because there are duplicates!
traffic_data = traffic_data.sort_values(by=["Timestamp","LocationLatitude", "LocationLongitude", "RadioOperatorName", "RadioNetworkGeneration", "TrafficDirection"], ignore_index=True)
traffic_data.head(10)
# Out:
#                   Timestamp  LocationLatitude  LocationLongitude  \
# 0 2019-11-01 18:00:00+00:00         24.639288          46.728962
# 1 2019-11-01 18:00:00+00:00         24.639288          46.728962
# 2 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 3 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 4 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 5 2019-11-01 18:15:00+00:00         24.639288          46.728962
# 6 2019-11-01 18:30:00+00:00         24.626589          46.689250
# 7 2019-11-01 18:30:00+00:00         24.626589          46.689250
# 8 2019-11-01 18:30:00+00:00         24.626589          46.689250
# 9 2019-11-01 18:30:00+00:00         24.626589          46.689250
#
#   RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile                     4G        Operator B
# 1              Mobile                     4G        Operator B
# 2              Mobile                     3G        Operator B
# 3              Mobile                     3G        Operator B
# 4              Mobile                     4G        Operator B
# 5              Mobile                     4G        Operator B
# 6              Mobile                     4G        Operator C
# 7              Mobile                     4G        Operator C
# 8              Mobile                     4G        Operator C
# 9              Mobile                     4G        Operator C
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      45.701516                Enabled
# 1           Uplink       1.740874                Enabled
# 2         Downlink       5.182752                Enabled
# 3           Uplink       0.390352                Enabled
# 4         Downlink      30.303686                Enabled
# 5           Uplink       1.083652                Enabled
# 6         Downlink       0.005951                Enabled
# 7         Downlink       2.263094                Enabled
# 8           Uplink       1.889517                Enabled
# 9           Uplink       0.011245                Enabled

# %% [markdown]
# We can see some duplicates here in the head of the dataframe, all the fields are the same except for the Traffic Volume. I'll use the pandasql to take he average of the traffic volume in these duplicate rows

# %%
query = """
SELECT Timestamp, LocationLatitude, LocationLongitude, RadioConnectionType, RadioNetworkGeneration, RadioOperatorName, TrafficDirection, SUM(TrafficVolume) AS TrafficVolume, RadioMobileDataEnabled
FROM traffic_data
GROUP BY Timestamp, LocationLatitude, LocationLongitude, RadioConnectionType, RadioNetworkGeneration, RadioOperatorName, TrafficDirection, RadioMobileDataEnabled
"""
traffic_data_grouped = sqldf(query)

# %%
traffic_data_grouped.head(10)
# Out:
#                     Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-01 18:00:00.000000         24.639288          46.728962
# 1  2019-11-01 18:00:00.000000         24.639288          46.728962
# 2  2019-11-01 18:15:00.000000         24.639288          46.728962
# 3  2019-11-01 18:15:00.000000         24.639288          46.728962
# 4  2019-11-01 18:15:00.000000         24.639288          46.728962
# 5  2019-11-01 18:15:00.000000         24.639288          46.728962
# 6  2019-11-01 18:30:00.000000         24.626589          46.689250
# 7  2019-11-01 18:30:00.000000         24.626589          46.689250
# 8  2019-11-01 18:30:00.000000         24.639288          46.728962
# 9  2019-11-01 18:30:00.000000         24.639288          46.728962
#
#   RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile                     4G        Operator B
# 1              Mobile                     4G        Operator B
# 2              Mobile                     3G        Operator B
# 3              Mobile                     3G        Operator B
# 4              Mobile                     4G        Operator B
# 5              Mobile                     4G        Operator B
# 6              Mobile                     4G        Operator C
# 7              Mobile                     4G        Operator C
# 8              Mobile                     4G        Operator B
# 9              Mobile                     4G        Operator B
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      45.701516                Enabled
# 1           Uplink       1.740874                Enabled
# 2         Downlink       5.182752                Enabled
# 3           Uplink       0.390352                Enabled
# 4         Downlink      30.303686                Enabled
# 5           Uplink       1.083652                Enabled
# 6         Downlink       2.269045                Enabled
# 7           Uplink       1.900762                Enabled
# 8         Downlink       0.056850                Enabled
# 9           Uplink       0.069332                Enabled

# %%
traffic_data_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138067 entries, 0 to 138066
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138067 non-null  object
#  1   LocationLatitude        138067 non-null  float64
#  2   LocationLongitude       138067 non-null  float64
#  3   RadioConnectionType     138067 non-null  object
#  4   RadioNetworkGeneration  138067 non-null  object
#  5   RadioOperatorName       138067 non-null  object
#  6   TrafficDirection        138067 non-null  object
#  7   TrafficVolume           138067 non-null  float64
#  8   RadioMobileDataEnabled  138067 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 9.5+ MB

# %%
traffic_data_grouped["Timestamp"] = pd.to_datetime(traffic_data_grouped["Timestamp"],
                                                    format="%Y-%m-%d %H:%M:%S.%f%z", 
                                                    utc=True, 
                                                    errors='coerce')

traffic_data_grouped[cols] = traffic_data_grouped[cols].astype('category')

# %%
traffic_data_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138067 entries, 0 to 138066
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               138067 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        138067 non-null  float64
#  2   LocationLongitude       138067 non-null  float64
#  3   RadioConnectionType     138067 non-null  category
#  4   RadioNetworkGeneration  138067 non-null  category
#  5   RadioOperatorName       138067 non-null  category
#  6   TrafficDirection        138067 non-null  category
#  7   TrafficVolume           138067 non-null  float64
#  8   RadioMobileDataEnabled  138067 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 4.9 MB

# %%
Downlink_mask = traffic_data_grouped.TrafficDirection == "Downlink"
Downlink_df = traffic_data_grouped[Downlink_mask]

Uplink_mask = traffic_data_grouped.TrafficDirection == "Uplink"
Uplink_df = traffic_data_grouped[Uplink_mask]

# %%
print(Uplink_df.info())
print(Downlink_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69007 entries, 1 to 138066
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               69007 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        69007 non-null  float64
#  2   LocationLongitude       69007 non-null  float64
#  3   RadioConnectionType     69007 non-null  category
#  4   RadioNetworkGeneration  69007 non-null  category
#  5   RadioOperatorName       69007 non-null  category
#  6   TrafficDirection        69007 non-null  category
#  7   TrafficVolume           69007 non-null  float64
#  8   RadioMobileDataEnabled  69007 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 3.0 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69060 entries, 0 to 138065
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               69060 non-null  datetime64[ns, UTC]
#  1   LocationLatitude        69060 non-null  float64
#  2   LocationLongitude       69060 non-null  float64
#  3   RadioConnectionType     69060 non-null  category
#  4   RadioNetworkGeneration  69060 non-null  category
#  5   RadioOperatorName       69060 non-null  category
#  6   TrafficDirection        69060 non-null  category
#  7   TrafficVolume           69060 non-null  float64
#  8   RadioMobileDataEnabled  69060 non-null  category
# dtypes: category(5), datetime64[ns, UTC](1), float64(3)
# memory usage: 3.0 MB
# None

# %%
Uplink_df.head(10)
# Out:
#                    Timestamp  LocationLatitude  LocationLongitude  \
# 1  2019-11-01 18:00:00+00:00         24.639288          46.728962
# 3  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 5  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 7  2019-11-01 18:30:00+00:00         24.626589          46.689250
# 9  2019-11-01 18:30:00+00:00         24.639288          46.728962
# 11 2019-11-01 18:45:00+00:00         24.626589          46.689250
# 13 2019-11-01 18:45:00+00:00         24.641806          46.715973
# 15 2019-11-01 19:00:00+00:00         24.619022          46.721550
# 17 2019-11-01 19:00:00+00:00         24.626589          46.689250
# 19 2019-11-01 19:15:00+00:00         24.619022          46.721550
#
#    RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 1               Mobile                     4G        Operator B
# 3               Mobile                     3G        Operator B
# 5               Mobile                     4G        Operator B
# 7               Mobile                     4G        Operator C
# 9               Mobile                     4G        Operator B
# 11              Mobile                     4G        Operator C
# 13              Mobile                     4G        Operator B
# 15              Mobile                     4G        Operator B
# 17              Mobile                     4G        Operator C
# 19              Mobile                     4G        Operator B
#
#    TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 1            Uplink       1.740874                Enabled
# 3            Uplink       0.390352                Enabled
# 5            Uplink       1.083652                Enabled
# 7            Uplink       1.900762                Enabled
# 9            Uplink       0.069332                Enabled
# 11           Uplink       2.470590                Enabled
# 13           Uplink       0.337878                Enabled
# 15           Uplink       0.133907                Enabled
# 17           Uplink       2.151763                Enabled
# 19           Uplink       0.482521                Enabled

# %%
Uplink_df.sample(20)
# Out:
#                        Timestamp  LocationLatitude  LocationLongitude  \
# 18239  2019-11-02 10:15:00+00:00         24.565266          46.687145
# 133146 2019-11-04 18:30:00+00:00         24.791096          46.644913
# 45494  2019-11-02 20:30:00+00:00         24.747229          46.775444
# 133417 2019-11-04 18:45:00+00:00         24.613800          46.693867
# 78650  2019-11-03 15:30:00+00:00         24.637959          46.844960
# 121163 2019-11-04 14:15:00+00:00         24.802107          46.603460
# 117388 2019-11-04 13:00:00+00:00         24.687786          46.847958
# 65465  2019-11-03 10:30:00+00:00         24.819078          46.631058
# 99185  2019-11-04 04:45:00+00:00         24.524529          46.869700
# 95532  2019-11-03 23:45:00+00:00         24.822601          46.651695
# 81484  2019-11-03 16:30:00+00:00         24.569735          46.833637
# 78716  2019-11-03 15:30:00+00:00         24.675295          46.672020
# 71415  2019-11-03 13:00:00+00:00         24.679045          46.595500
# 33471  2019-11-02 15:45:00+00:00         24.603884          46.593105
# 51398  2019-11-03 03:45:00+00:00         24.600735          46.837670
# 71920  2019-11-03 13:15:00+00:00         24.594639          46.736176
# 124151 2019-11-04 15:30:00+00:00         24.585980          46.556934
# 59137  2019-11-03 08:00:00+00:00         24.814040          46.882397
# 109329 2019-11-04 09:45:00+00:00         24.659807          46.718380
# 50480  2019-11-03 02:45:00+00:00         24.799017          46.737144
#
#        RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 18239               Mobile                     3G        Operator A
# 133146              Mobile                     4G        Operator A
# 45494               Mobile                     3G        Operator B
# 133417              Mobile                     4G        Operator B
# 78650               Mobile                     4G        Operator A
# 121163              Mobile                     4G        Operator A
# 117388              Mobile                     4G        Operator B
# 65465               Mobile                     4G        Operator B
# 99185               Mobile                     3G        Operator A
# 95532               Mobile                     4G        Operator B
# 81484               Mobile                     3G        Operator B
# 78716               Mobile                     4G        Operator A
# 71415               Mobile                     4G        Operator A
# 33471               Mobile                     4G        Operator B
# 51398               Mobile                     4G        Operator C
# 71920               Mobile                     4G        Operator B
# 124151              Mobile                     4G        Operator A
# 59137               Mobile                     4G        Operator A
# 109329              Mobile                     4G        Operator A
# 50480               Mobile                     4G        Operator B
#
#        TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 18239            Uplink       0.253866                Enabled
# 133146           Uplink       2.921121                Enabled
# 45494            Uplink       0.554666                Enabled
# 133417           Uplink       0.157983                Enabled
# 78650            Uplink       0.410840                Enabled
# 121163           Uplink       1.192074                Enabled
# 117388           Uplink       0.032023                Enabled
# 65465            Uplink       0.339435                Enabled
# 99185            Uplink       0.038223                Enabled
# 95532            Uplink       0.423772                Enabled
# 81484            Uplink       0.054234                Enabled
# 78716            Uplink       0.588076                Enabled
# 71415            Uplink       0.506463                Enabled
# 33471            Uplink       0.032759                Enabled
# 51398            Uplink       0.294591                Enabled
# 71920            Uplink       0.287230                Enabled
# 124151           Uplink       0.145870                Enabled
# 59137            Uplink       0.078521                Enabled
# 109329           Uplink       1.756678                Enabled
# 50480            Uplink       0.359905                Enabled

# %%
Downlink_df.head(10)
# Out:
#                    Timestamp  LocationLatitude  LocationLongitude  \
# 0  2019-11-01 18:00:00+00:00         24.639288          46.728962
# 2  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 4  2019-11-01 18:15:00+00:00         24.639288          46.728962
# 6  2019-11-01 18:30:00+00:00         24.626589          46.689250
# 8  2019-11-01 18:30:00+00:00         24.639288          46.728962
# 10 2019-11-01 18:45:00+00:00         24.626589          46.689250
# 12 2019-11-01 18:45:00+00:00         24.640503          46.716290
# 14 2019-11-01 19:00:00+00:00         24.619022          46.721550
# 16 2019-11-01 19:00:00+00:00         24.626589          46.689250
# 18 2019-11-01 19:15:00+00:00         24.619022          46.721550
#
#    RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0               Mobile                     4G        Operator B
# 2               Mobile                     3G        Operator B
# 4               Mobile                     4G        Operator B
# 6               Mobile                     4G        Operator C
# 8               Mobile                     4G        Operator B
# 10              Mobile                     4G        Operator C
# 12              Mobile                     4G        Operator B
# 14              Mobile                     4G        Operator B
# 16              Mobile                     4G        Operator C
# 18              Mobile                     4G        Operator B
#
#    TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0          Downlink      45.701516                Enabled
# 2          Downlink       5.182752                Enabled
# 4          Downlink      30.303686                Enabled
# 6          Downlink       2.269045                Enabled
# 8          Downlink       0.056850                Enabled
# 10         Downlink       2.743515                Enabled
# 12         Downlink       8.589538                Enabled
# 14         Downlink       0.331708                Enabled
# 16         Downlink       2.475489                Enabled
# 18         Downlink       1.351583                Enabled

# %%
Downlink_df.sample(20)
# Out:
#                        Timestamp  LocationLatitude  LocationLongitude  \
# 16697  2019-11-02 09:30:00+00:00         24.706203          46.837510
# 72855  2019-11-03 13:30:00+00:00         24.675873          46.665740
# 63902  2019-11-03 10:00:00+00:00         24.713938          46.698530
# 10711  2019-11-02 07:00:00+00:00         24.587673          46.545135
# 45436  2019-11-02 20:30:00+00:00         24.697239          46.838840
# 80726  2019-11-03 16:15:00+00:00         24.565428          46.519120
# 63042  2019-11-03 09:45:00+00:00         24.632008          46.554670
# 88337  2019-11-03 18:45:00+00:00         24.931993          46.715363
# 82686  2019-11-03 16:45:00+00:00         24.774775          46.773396
# 61604  2019-11-03 09:00:00+00:00         24.811638          46.747215
# 132803 2019-11-04 18:30:00+00:00         24.641647          46.721996
# 15897  2019-11-02 09:15:00+00:00         24.632774          46.802773
# 35518  2019-11-02 16:30:00+00:00         24.560114          46.865110
# 30455  2019-11-02 14:45:00+00:00         24.587849          46.770638
# 22215  2019-11-02 11:45:00+00:00         24.607819          46.764820
# 92796  2019-11-03 21:00:00+00:00         24.734934          46.847427
# 63994  2019-11-03 10:00:00+00:00         24.751709          46.684265
# 86640  2019-11-03 18:15:00+00:00         24.636900          46.720055
# 94485  2019-11-03 22:30:00+00:00         24.559427          46.865580
# 10815  2019-11-02 07:00:00+00:00         24.633915          46.746490
#
#        RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 16697               Mobile                     4G        Operator B
# 72855               Mobile                     4G        Operator A
# 63902               Mobile                     3G        Operator A
# 10711               Mobile                     3G        Operator A
# 45436               Mobile                     4G        Operator C
# 80726               Mobile                     4G        Operator A
# 63042               Mobile                     4G        Operator A
# 88337               Mobile                     4G        Operator A
# 82686               Mobile                     4G        Operator B
# 61604                 WiFi                     3G        Operator C
# 132803              Mobile                     4G        Operator A
# 15897               Mobile                     4G        Operator A
# 35518                 WiFi                     4G        Operator A
# 30455               Mobile                     4G        Operator B
# 22215               Mobile                     3G        Operator A
# 92796               Mobile                     4G        Operator A
# 63994               Mobile                     4G        Operator A
# 86640               Mobile                     4G        Operator A
# 94485               Mobile                     4G        Operator A
# 10815               Mobile                     3G        Operator B
#
#        TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 16697          Downlink       0.084472                Enabled
# 72855          Downlink       0.290013                Enabled
# 63902          Downlink      12.751518                Enabled
# 10711          Downlink       0.198847                Enabled
# 45436          Downlink     102.471853                Enabled
# 80726          Downlink      16.823705                Enabled
# 63042          Downlink      62.259483                Enabled
# 88337          Downlink       0.052261                Enabled
# 82686          Downlink      83.784539                Enabled
# 61604          Downlink     313.399942                Enabled
# 132803         Downlink       8.752582                Enabled
# 15897          Downlink       1.822297                Enabled
# 35518          Downlink      18.653441                Enabled
# 30455          Downlink       2.910095                Enabled
# 22215          Downlink       0.211814                Enabled
# 92796          Downlink       1.283052                Enabled
# 63994          Downlink     121.912158                Enabled
# 86640          Downlink       0.422380                Enabled
# 94485          Downlink      15.064739                Enabled
# 10815          Downlink       0.380713                Enabled

# %%
Uplink_df.describe().transpose()
# Out:
#                      count       mean        std        min        25%  \
# LocationLatitude   69007.0  24.689345   0.096779  24.435455  24.614894
# LocationLongitude  69007.0  46.726149   0.090212  46.358420  46.668570
# TrafficVolume      69007.0   3.235700  93.767577   0.001240   0.107215
#
#                          50%        75%          max
# LocationLatitude   24.685047  24.759370    25.034151
# LocationLongitude  46.719044  46.787045    47.180748
# TrafficVolume       0.327091   1.017883  8439.682444

# %%
Downlink_df.describe().transpose()
# Out:
#                      count       mean          std        min        25%  \
# LocationLatitude   69060.0  24.689421     0.096643  24.435455  24.615019
# LocationLongitude  69060.0  46.726108     0.090075  46.358420  46.668563
# TrafficVolume      69060.0  44.419884  1512.255292   0.001060   0.249153
#
#                          50%        75%            max
# LocationLatitude   24.685434  24.759370      25.034151
# LocationLongitude  46.719149  46.786918      47.180748
# TrafficVolume       1.365706  10.901087  104022.000000

# %%
fig, ((plot1, plot2), (plot3, plot4)) = plt.subplots(2,2)
# first row
plot1.hist(Downlink_df["TrafficVolume"], bins=100)
plot1.set_title("DownLink Traffic Histogram")
plot2.hist(Uplink_df["TrafficVolume"], bins=100)
plot2.set_title("UpLink Traffic Histogram")
# Second row
plot3.hist(Downlink_df["TrafficVolume"], bins=100, log=True)
plot3.set_title("DownLink Traffic Histogram Log")
plot4.hist(Uplink_df["TrafficVolume"], bins=100, log=True)
plot4.set_title("UpLink Traffic Histogram Log")

fig.set_figwidth(25)
fig.set_figheight(10) 
plt.show()

# %% [markdown]
# The skewness in the dataset is clearly visible most the datapoints have a small value for the traffic volume with few datapoint having a very large value.

# %%
df = Downlink_df.copy()

# This step is needed to prepare the data to be plotted on the map
df["LocationLongitude"], df["LocationLatitude"] = lnglat_to_meters(df["LocationLongitude"], df["LocationLatitude"])

# %%
# Index must be resetted before plotting
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#                   Timestamp  LocationLatitude  LocationLongitude  \
# 0 2019-11-01 18:00:00+00:00      2.831504e+06       5.201844e+06
# 1 2019-11-01 18:15:00+00:00      2.831504e+06       5.201844e+06
# 2 2019-11-01 18:15:00+00:00      2.831504e+06       5.201844e+06
# 3 2019-11-01 18:30:00+00:00      2.829949e+06       5.197424e+06
# 4 2019-11-01 18:30:00+00:00      2.831504e+06       5.201844e+06
#
#   RadioConnectionType RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile                     4G        Operator B
# 1              Mobile                     3G        Operator B
# 2              Mobile                     4G        Operator B
# 3              Mobile                     4G        Operator C
# 4              Mobile                     4G        Operator B
#
#   TrafficDirection  TrafficVolume RadioMobileDataEnabled
# 0         Downlink      45.701516                Enabled
# 1         Downlink       5.182752                Enabled
# 2         Downlink      30.303686                Enabled
# 3         Downlink       2.269045                Enabled
# 4         Downlink       0.056850                Enabled

# %% [markdown]
# # Visualization:
# A map per operator is created to identify the areas with high traffic volume.
# This is done by two method: using holoviews and using matplotlib.

# %%
esri = hv.element.tiles.ESRI().redim(x="Longtitude", y="Latitude").opts(alpha=0.2, width=1000, height=700, bgcolor='black')
COLORS = {"Operator A": cc.kr, "Operator B": cc.kg, "Operator C": cc.kb}

def traffic_plot(operator_name):
    """Plots a hexbin for each operator where the size of each hex depends on the counts of values that falls inside this hex"""
    df_operator = df[df["RadioOperatorName"] == operator_name]
    if (len(df_operator) == 0 ):
        return esri
    operator_tiles =  hv.element.HexTiles(df_operator, kdims=["LocationLongitude", "LocationLatitude"], vdims=["TrafficVolume"])
    operator_tiles.opts(cmap=COLORS[operator_name], 
                        alpha=0.8, 
                        cnorm="eq_hist", 
                        tools=["hover"], 
                        width=900, 
                        height=700, 
                        scale=(hv.dim('TrafficVolume').norm()*0.9)+0.3
                       )
    return (esri * operator_tiles).opts(hv.opts.HexTiles(aggregator=np.sum))

    
operator_select = pn.widgets.RadioButtonGroup(options=list(COLORS.keys()))
interactive = pn.bind(traffic_plot, operator_select)
first_app = pn.Column(operator_select, interactive)
first_app
# Out:
# Column
#     [0] RadioButtonGroup(options=['Operator A', ...], value='Operator A')
#     [1] ParamFunction(function)

# %% [markdown]
# We can also create a static map using the matplotlib api provided by pandas.

# %%
def traffic_map_static(operator_name):
    df_operator = df[df["RadioOperatorName"] == operator_name]

    return df_operator.plot.hexbin( x="LocationLongitude", 
                                    y="LocationLatitude", 
                                    C="TrafficVolume",
                                    reduce_C_function=np.sum, 
                                    cmap="viridis",
                                    figsize=(20,15)
                                    )
traffic_map_static("Operator B")
plt.show()

# %%
# traffic_data_grouped.to_parquet("./Data/Traffic_volume_data.parq")
